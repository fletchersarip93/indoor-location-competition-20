# %%
import pandas as pd
import os
import my_kaggle_util as util
import numpy as np
from tqdm import tqdm

# %% [markdown]
# Preview of how the path data text file looks like:

# %%
with open(util.download_file('train/5cd56b5ae2acfd2d33b58548/2F/5cf214bfc852a70008c01609.txt'), 'r', encoding='utf-8') as file:

# %%
files_list = !kaggle competitions files indoor-location-navigation
files_list = files_list[2:]

# %%
train_files = [x for x in files_list if x.startswith('train/')]
test_files = [x for x in files_list if x.startswith('test/')]

# %%
downloaded_files = []
for f in tqdm(train_files):
    downloaded_files.append(util.download_file(f))
# Out:
#   8%|██████▏                                                                         | 91/1175 [00:29<05:46,  3.13it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-1e400975d5b1> in <module>
#       1 downloaded_files = []
#       2 for f in tqdm(train_files):
# ----> 3     downloaded_files.append(util.download_file(f))
#
# E:\Users\fsp1\Documents\Kaggle\indoor-location-competition-20\my_kaggle_util.py in download_file(file_path, competition_name)
#       7     output_path = os.path.join('kaggle_data', dirname)
#       8
# ----> 9     os.system(f'kaggle competitions download -c {competition_name} -f {file_path} -p {output_path}')
#      10     os.system(f'unzip {os.path.join(output_path, filename+".zip")} -d {output_path}')
#      11     os.system(f'rm {os.path.join(output_path, filename+".zip")}')
#
# KeyboardInterrupt:
